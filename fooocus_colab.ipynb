# %%
# 1. Installer matplotlib-inline dans le venv
# !uv pip install --python /content/venv matplotlib-inline

# 2. Lancer Fooocus en forçant le backend Matplotlib standard
# %cd /content/Fooocus
# !MPLBACKEND=Agg /content/venv/bin/python launch.py --share --always-high-vram

# %%
# 1. Aligner FastAPI, Pydantic et Starlette sur des versions 100 % compatibles avec Gradio 3.41.2
# !uv pip install --python /content/venv "pydantic<2.0" "fastapi<0.100.0" "starlette<0.28.0" "gradio==3.41.2"

# 2. Relancer Fooocus
# %cd /content/Fooocus
# !MPLBACKEND=Agg /content/venv/bin/python launch.py --share --always-high-vram
# Out:
# Using Python 3.10.12 environment at: /content/venv
# Resolved 56 packages in 316ms
# Prepared 3 packages in 100ms
# Uninstalled 3 packages in 8ms
# Installed 3 packages in 4ms
#  - fastapi==0.141.1
#  + fastapi==0.99.1
#  - pydantic==2.13.5
#  + pydantic==1.10.26
#  - starlette==1.6.0
#  + starlette==0.27.0
# /content/Fooocus
# [System ARGV] ['launch.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Jun 22 2026, 18:55:27) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 14913 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# [System ARGV] ['launch.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Jun 22 2026, 18:55:27) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# ...
